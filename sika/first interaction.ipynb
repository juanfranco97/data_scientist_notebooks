# %% [markdown]
# # Where there are more sika cases?

# %%
import pandas as pd

# %%
df_sika = pd.read_csv('cdc_zika.csv')
df_sika
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        report_date                      location location_type  \
# 0       2016-03-19        Argentina-Buenos_Aires      province
# 1       2016-03-19        Argentina-Buenos_Aires      province
# 2       2016-03-19        Argentina-Buenos_Aires      province
# 3       2016-03-19        Argentina-Buenos_Aires      province
# 4       2016-03-19        Argentina-Buenos_Aires      province
# ...            ...                           ...           ...
# 107614  2016-06-28  United_States_Virgin_Islands     territory
# 107615  2016-06-28  United_States_Virgin_Islands     territory
# 107616  2016-06-28  United_States_Virgin_Islands     territory
# 107617  2016-06-28  United_States_Virgin_Islands     territory
# ...

# %%
df_sika.describe(include='all')
# Out:
#        report_date                      location location_type  \
# count       107612                        107612        107612
# unique         128                          1673            11
# top     2016-04-23  United_States_Virgin_Islands  municipality
# freq          4677                           413         87557
# mean           NaN                           NaN           NaN
# std            NaN                           NaN           NaN
# min            NaN                           NaN           NaN
# 25%            NaN                           NaN           NaN
# 50%            NaN                           NaN           NaN
# 75%            NaN                           NaN           NaN
# max            NaN                           NaN           NaN
#
#                        data_field data_field_code  time_period  \
# count                      107612          107612          0.0
# unique                        148             153          NaN
# ...

# %%
df_sika['unit'].unique()
# Out:
# array(['cases', 'municipalities', nan], dtype=object)

# %%
copy_sika = df_sika.copy()

# %%
copy_sika
# Out:
#        report_date                      location location_type  \
# 0       2016-03-19        Argentina-Buenos_Aires      province
# 1       2016-03-19        Argentina-Buenos_Aires      province
# 2       2016-03-19        Argentina-Buenos_Aires      province
# 3       2016-03-19        Argentina-Buenos_Aires      province
# 4       2016-03-19        Argentina-Buenos_Aires      province
# ...            ...                           ...           ...
# 107614  2016-06-28  United_States_Virgin_Islands     territory
# 107615  2016-06-28  United_States_Virgin_Islands     territory
# 107616  2016-06-28  United_States_Virgin_Islands     territory
# 107617  2016-06-28  United_States_Virgin_Islands     territory
# 107618  2016-06-28  United_States_Virgin_Islands     territory
#
#                                  data_field data_field_code  time_period  \
# 0          cumulative_confirmed_local_cases          AR0001          NaN
# ...

# %%
copy_sika.drop(['time_period', 'time_period_type'], axis=1,inplace=True)

# %%
copy_sika
# Out:
#        report_date                      location location_type  \
# 0       2016-03-19        Argentina-Buenos_Aires      province
# 1       2016-03-19        Argentina-Buenos_Aires      province
# 2       2016-03-19        Argentina-Buenos_Aires      province
# 3       2016-03-19        Argentina-Buenos_Aires      province
# 4       2016-03-19        Argentina-Buenos_Aires      province
# ...            ...                           ...           ...
# 107614  2016-06-28  United_States_Virgin_Islands     territory
# 107615  2016-06-28  United_States_Virgin_Islands     territory
# 107616  2016-06-28  United_States_Virgin_Islands     territory
# 107617  2016-06-28  United_States_Virgin_Islands     territory
# 107618  2016-06-28  United_States_Virgin_Islands     territory
#
#                                  data_field data_field_code value   unit
# 0          cumulative_confirmed_local_cases          AR0001     0  cases
# ...

# %%
df=copy_sika.loc[copy_sika['unit']=='municipalities']

# %%
df.describe(include='all')
# Out:
#        report_date      location location_type                 data_field  \
# count         1093          1093          1093                       1093
# unique          21            27             1                          2
# top     2016-04-02  Brazil-Goias         state  municipality_microcephaly
# freq            54            41          1093                        553
#
#        data_field_code value            unit
# count             1093  1005            1093
# unique               2   137               1
# top             BR0004     1  municipalities
# freq               553   115            1093

# %%
copy_sika.isnull().count()
# Out:
# report_date        107619
# location           107619
# location_type      107619
# data_field         107619
# data_field_code    107619
# value              107619
# unit               107619
# dtype: int64

# %%
copy_sika.loc[2414]
# Out:
# report_date                              2016-02-27
# location                           Brazil-Sao_Paulo
# location_type                                 state
# data_field         microcephaly_under_investigation
# data_field_code                              BR0001
# value                                         125*5
# unit                                          cases
# Name: 2414, dtype: object

# %%
copy_sika.loc[copy_sika['value']==0]
# Out:
#        report_date                       location location_type  \
# 65536   2016-05-07     Colombia-Antioquia-La_Ceja  municipality
# 65539   2016-05-07    Colombia-Antioquia-La_Union  municipality
# 65540   2016-05-07    Colombia-Antioquia-Liborina  municipality
# 65542   2016-05-07   Colombia-Antioquia-Marinilla  municipality
# 65543   2016-05-07  Colombia-Antioquia-Montebello  municipality
# ...            ...                            ...           ...
# 107498  2016-06-01   United_States_Virgin_Islands     territory
# 107525  2016-06-07   United_States_Virgin_Islands     territory
# 107552  2016-06-14   United_States_Virgin_Islands     territory
# 107579  2016-06-21   United_States_Virgin_Islands     territory
# 107606  2016-06-28   United_States_Virgin_Islands     territory
#
#                        data_field data_field_code value   unit
# 65536   zika_confirmed_laboratory          CO0001     0  cases
# 65539   zika_confirmed_laboratory          CO0001     0  cases
# ...

# %%
copy_sika.dtypes
# Out:
# report_date        object
# location           object
# location_type      object
# data_field         object
# data_field_code    object
# value              object
# unit               object
# dtype: object

# %%
# Agrupaciones, el .count() es que cuente las filas, También puede ser .sum(), .mean(), etc.
df.groupby(by=["Col1", "Col2"]).count()

# %%
copy_sika
# Out:
#        report_date                      location location_type  \
# 0       2016-03-19        Argentina-Buenos_Aires      province
# 1       2016-03-19        Argentina-Buenos_Aires      province
# 2       2016-03-19        Argentina-Buenos_Aires      province
# 3       2016-03-19        Argentina-Buenos_Aires      province
# 4       2016-03-19        Argentina-Buenos_Aires      province
# ...            ...                           ...           ...
# 107614  2016-06-28  United_States_Virgin_Islands     territory
# 107615  2016-06-28  United_States_Virgin_Islands     territory
# 107616  2016-06-28  United_States_Virgin_Islands     territory
# 107617  2016-06-28  United_States_Virgin_Islands     territory
# 107618  2016-06-28  United_States_Virgin_Islands     territory
#
#                                  data_field data_field_code value   unit
# 0          cumulative_confirmed_local_cases          AR0001     0  cases
# ...

# %%
copy_sika.groupby(by=['location']).count()
# Out:
#                                            report_date  location_type  \
# location
# Argentina-Buenos_Aires                              84             84
# Argentina-CABA                                      84             84
# Argentina-Catamarca                                 84             84
# Argentina-Chaco                                     84             84
# Argentina-Chubut                                    84             84
# ...                                                ...            ...
# United_States-Wisconsin                              6              6
# United_States_Virgin_Islands                       413            413
# United_States_Virgin_Islands-Saint_Croix            32             32
# United_States_Virgin_Islands-Saint_John             32             32
# United_States_Virgin_Islands-Saint_Thomas           32             32
#
#                                            data_field  data_field_code  value  \
# location
# ...

# %%
copy_sika.groupby(by=['location']).count().sort_values(by=['value'], ascending=False).head(10)
# Out:
#                                       report_date  location_type  data_field  \
# location
# United_States_Virgin_Islands                  413            413         413
# El_Salvador                                   305            305         305
# Puerto_Rico                                   260            260         260
# Ecuador                                       225            225         225
# Dominican_Republic                            201            201         201
# Dominican_Republic-Distrito_Nacional          175            175         175
# Dominican_Republic-Santo_Domingo              172            172         172
# Brazil-Goias                                  171            171         171
# Brazil-Pernambuco                             171            171         171
# Brazil-Alagoas                                171            171         171
#
#                                       data_field_code  value  unit
# location
# ...

# %%
copy_sika.groupby(by=['location']).count().max()
# Out:
# report_date        413
# location_type      413
# data_field         413
# data_field_code    413
# value              413
# unit               413
# dtype: int64

# %%
most_cases=copy_sika.loc[copy_sika['location']=='United_States_Virgin_Islands']
most_cases.sample(10)
# Out:
#        report_date                      location location_type  \
# 107132  2016-02-16  United_States_Virgin_Islands     territory
# 107235  2016-03-22  United_States_Virgin_Islands     territory
# 107355  2016-04-19  United_States_Virgin_Islands     territory
# 107277  2016-04-05  United_States_Virgin_Islands     territory
# 107238  2016-03-22  United_States_Virgin_Islands     territory
# 107137  2016-02-23  United_States_Virgin_Islands     territory
# 107558  2016-06-14  United_States_Virgin_Islands     territory
# 107609  2016-06-28  United_States_Virgin_Islands     territory
# 107300  2016-04-12  United_States_Virgin_Islands     territory
# 107555  2016-06-14  United_States_Virgin_Islands     territory
#
#                   data_field data_field_code value   unit
# 107132     confirmed_malaise          VI0020     1  cases
# 107235      confirmed_female          VI0011     8  cases
# 107355  confirmed_arthralgia          VI0014    12  cases
# ...

# %%
most_cases.describe(include='all')
# Out:
#        report_date                      location location_type  \
# count          413                           413           413
# unique          19                             1             1
# top     2016-04-19  United_States_Virgin_Islands     territory
# freq            42                           413           413
#
#                    data_field data_field_code  value   unit
# count                     413             413  413.0    413
# unique                     21              21   72.0      1
# top     confirmed_age_under20          VI0020    2.0  cases
# freq                       20              20   38.0    413
